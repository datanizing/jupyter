# %% [markdown]
# # Fortschrittsanzeige und Datentransformationen

# %% [markdown]
# Häufig wirst du in Jupyter-Notebooks mit Daten arbeiten. Manchmal können Operationen *lange dauern* und du möchtest jeweils immer über den aktuellen Status informiert sein.
#
# Sehr oft liegen Daten nicht in exakt der Form vor, in der du sie für die Weiterverarbeitung benötigst. In `pandas` gibt es sehr leistungsfähige Operationen zur *Datentransformation*, die du hier kennenlernen wirst.

# %% [markdown]
# ## Fortschrittsanzeige

# %% [markdown]
# Damit du keine separate Schleife mit langer Laufzeit implementieren musst, simulierst du das einfach mit einem `sleep`, der die Laufzeit der Anweisung in der Schleife auf etwa 10ms erhöht.

# %%
import time
for i in range(1000):
    time.sleep(0.01)

# %% [markdown]
# Nach 10s ist der Spuk vorbei, so lange kannst du natürlich warten. Oft dauert es aber deutlich länger und du möchtest wissen, wie weit der Prozess schon fortgeschritten ist.
#
# Dabei hilft dir das Paket `tqdm`. Statt `range` verwendest du einfach `trange`, ansonsten ändert sich nichts. Allerdings sieht das Ergebnis schon etwas anders aus:

# %%
from tqdm.auto import trange
for i in trange(1000):
    time.sleep(0.01)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# Neben dem Fortschritt zeigt `tqdm` auch noch den prozentualen Fertigstellungsgrad, die Iterationen pro Sekunde und die erwartete Restlaufzeit an. Das wirst du oft brauchen, es ist super nützlich.
#
# Es ist natürlich ziemlich praktisch, dass `tqdm` die Funktion `trange` anbietet. Aber sicher möchtest du nicht immer nur mit `range` arbeiten, sondern hast oft auch andere Objekte.
#
# Zum Glück kann `tqdm` auch damit umgehen. Bei bestimmten (iterierbaren) Objekten musst du noch den Parameter `total` eingeben, damit die gesamte Laufzeit abgeschätzt werden kann. Bei `range` ist das nicht notwendig.
#
# `tqdm` kann außerdem auch mit geschachtelten Schleifen umgehen:

# %%
from tqdm.auto import tqdm
for i in tqdm(range(10), desc="first"):
    for j in tqdm(range(100), desc="second"):
        time.sleep(0.01)
# Out:
# first:   0%|          | 0/10 [00:00<?, ?it/s]
# second:   0%|          | 0/100 [00:00<?, ?it/s]
# second:   0%|          | 0/100 [00:00<?, ?it/s]
# second:   0%|          | 0/100 [00:00<?, ?it/s]
# second:   0%|          | 0/100 [00:00<?, ?it/s]
# second:   0%|          | 0/100 [00:00<?, ?it/s]
# second:   0%|          | 0/100 [00:00<?, ?it/s]
# second:   0%|          | 0/100 [00:00<?, ?it/s]
# second:   0%|          | 0/100 [00:00<?, ?it/s]
# second:   0%|          | 0/100 [00:00<?, ?it/s]
# second:   0%|          | 0/100 [00:00<?, ?it/s]

# %% [markdown]
# Sobald du längere Operationen in Schleifen durchführst, solltest du `tqdm` verwenden. Der zusätzliche Aufwand ist praktisch vernachlässigbar und du erhältst wesentlich mehr Kontrolle über deine Notebooks und den jeweiligen Bearbeitungsstand.
#
# Übrigens funktioniert `tqdm` auch auf der Konsole ziemlich gut und gibt dort (in ASCII-Zeichen) genau die gleichen Informationen aus!

# %% [markdown]
# ## Datentransformation

# %% [markdown]
# Häufig kannst du dir das Format nicht aussuchen, in dem Daten vorliegen. Im Gegenteil, in den allermeisten Fällen ist es schon ein ganz großes Glück, wenn du überhaupt Daten findest und auf die zugreifen kannst.
#
# Einen großen Fundus an Daten bietet dir [Eurostat](https://ec.europa.eu/eurostat), die Statistik-Behörde der Europäischen Union. Natürlich handelt es sich dabei um sehr spezielle Daten, allerdings hast du den großen Vorteil, dass du die Daten frei verwenden darfst und das Herunterladen kein Problem ist. Dafür gibt es nämlich ein Python-Paket `eurostat`:

# %%
# !pip install eurostat
# Out:
# Requirement already satisfied: eurostat in /home/cwinkler/.venv/jupyter-new/lib/python3.8/site-packages (0.2.3)
# Requirement already satisfied: pandas in /home/cwinkler/.venv/jupyter-new/lib/python3.8/site-packages (from eurostat) (1.2.4)
# Requirement already satisfied: pandasdmx<=0.9 in /home/cwinkler/.venv/jupyter-new/lib/python3.8/site-packages (from eurostat) (0.9)
# Requirement already satisfied: requests in /home/cwinkler/.venv/jupyter-new/lib/python3.8/site-packages (from eurostat) (2.25.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/cwinkler/.venv/jupyter-new/lib/python3.8/site-packages (from pandas->eurostat) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /home/cwinkler/.venv/jupyter-new/lib/python3.8/site-packages (from pandas->eurostat) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /home/cwinkler/.venv/jupyter-new/lib/python3.8/site-packages (from pandas->eurostat) (1.19.5)
# Requirement already satisfied: lxml in /home/cwinkler/.venv/jupyter-new/lib/python3.8/site-packages (from pandasdmx<=0.9->eurostat) (4.6.3)
# Requirement already satisfied: setuptools in /home/cwinkler/.venv/jupyter-new/lib/python3.8/site-packages (from pandasdmx<=0.9->eurostat) (56.0.0)
# Requirement already satisfied: jsonpath-rw in /home/cwinkler/.venv/jupyter-new/lib/python3.8/site-packages (from pandasdmx<=0.9->eurostat) (1.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/cwinkler/.venv/jupyter-new/lib/python3.8/site-packages (from requests->eurostat) (1.25.4)
# Requirement already satisfied: idna<3,>=2.5 in /home/cwinkler/.venv/jupyter-new/lib/python3.8/site-packages (from requests->eurostat) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/cwinkler/.venv/jupyter-new/lib/python3.8/site-packages (from requests->eurostat) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/cwinkler/.venv/jupyter-new/lib/python3.8/site-packages (from requests->eurostat) (2020.12.5)
# Requirement already satisfied: six>=1.5 in /home/cwinkler/.venv/jupyter-new/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->eurostat) (1.15.0)
# Requirement already satisfied: ply in /home/cwinkler/.venv/jupyter-new/lib/python3.8/site-packages (from jsonpath-rw->pandasdmx<=0.9->eurostat) (3.11)
# Requirement already satisfied: decorator in /home/cwinkler/.venv/jupyter-new/lib/python3.8/site-packages (from jsonpath-rw->pandasdmx<=0.9->eurostat) (4.4.2)

# %% [markdown]
# Alle Statistikdaten haben bei Eurostat ein Kürzel. In diesem Beispiel beschäftigst du dich mit den *Konsumindikatoren*, diese tragen das Kürzel `ei_bsco_m`. Es handelt sich dabei um sog. *business and consumer surveys*, die monatlich verdichtet sind (alternativ könntest du die auch auf das Quartal aggregiert herunterladen). Eine genauere Erklärung findest du [hier](https://ec.europa.eu/eurostat/cache/metadata/en/ei_bcs_esms.htm).
#
# Das Herunterladen der Daten ist nun sehr einfach:

# %%
import eurostat
df = eurostat.get_data_df("ei_bsco_m")

# %% [markdown]
# Betrachte im nächsten Schritt die Daten:

# %%
df
# Out:
#         indic s_adj unit geo\time  2021M07  2021M06  2021M05  2021M04  \
# 0    BS-CSMCI   NSA  BAL       AL    -12.9    -13.6    -15.6    -18.1
# 1    BS-CSMCI   NSA  BAL       AT      0.2     -0.6     -0.9    -10.5
# 2    BS-CSMCI   NSA  BAL       BE      2.9      4.1      1.1     -3.5
# 3    BS-CSMCI   NSA  BAL       BG    -16.5    -18.4    -22.2    -20.0
# 4    BS-CSMCI   NSA  BAL       CY    -23.5    -10.1    -15.8    -19.0
# ..        ...   ...  ...      ...      ...      ...      ...      ...
# 901  BS-UE-NY    SA  BAL       SE    -16.2    -17.7     -4.5      4.3
# 902  BS-UE-NY    SA  BAL       SI     21.8      9.3     21.4     45.4
# 903  BS-UE-NY    SA  BAL       SK     24.3     22.3     32.5     46.1
# 904  BS-UE-NY    SA  BAL       TR     33.4     28.5     36.5     36.0
# 905  BS-UE-NY    SA  BAL       UK      NaN      NaN      NaN      NaN
#
#      2021M03  2021M02  ...  1980M10  1980M09  1980M08  1980M07  1980M06  \
# 0      -19.8    -17.1  ...      NaN      NaN      NaN      NaN      NaN
# 1       -4.1     -8.6  ...      NaN      NaN      NaN      NaN      NaN
# 2       -3.0     -5.0  ...      NaN      NaN      NaN      NaN      NaN
# 3      -23.5    -29.8  ...      NaN      NaN      NaN      NaN      NaN
# 4      -22.6    -27.4  ...      NaN      NaN      NaN      NaN      NaN
# ..       ...      ...  ...      ...      ...      ...      ...      ...
# 901     13.9     16.2  ...      NaN      NaN      NaN      NaN      NaN
# 902     40.3     35.8  ...      NaN      NaN      NaN      NaN      NaN
# 903     58.9     57.4  ...      NaN      NaN      NaN      NaN      NaN
# 904     27.5     30.4  ...      NaN      NaN      NaN      NaN      NaN
# 905      NaN      NaN  ...      NaN      NaN      NaN      NaN      NaN
#
#      1980M05  1980M04  1980M03  1980M02  1980M01
# 0        NaN      NaN      NaN      NaN      NaN
# 1        NaN      NaN      NaN      NaN      NaN
# 2        NaN      NaN      NaN      NaN      NaN
# 3        NaN      NaN      NaN      NaN      NaN
# 4        NaN      NaN      NaN      NaN      NaN
# ..       ...      ...      ...      ...      ...
# 901      NaN      NaN      NaN      NaN      NaN
# 902      NaN      NaN      NaN      NaN      NaN
# 903      NaN      NaN      NaN      NaN      NaN
# 904      NaN      NaN      NaN      NaN      NaN
# 905      NaN      NaN      NaN      NaN      NaN
#
# [906 rows x 503 columns]

# %% [markdown]
# Nun beginnst du mit den Datentransformationen, und zwar zunächst mit den Spaltennamen:
#
# `geo\time` ist eine etwas unglückliche Bezeichnung, hier ist nur das Land gemeint, das kannst du einfach umbenennen:

# %%
df = df.rename(columns={"geo\\time": "country"})

# %% [markdown]
# Ebenso etwas merkwürdig sind die Monatsnamen in Form von `2021M04` etc., die du auch besser durch ein `datetime`-Objekt in Python ersetzt:

# %%
from datetime import datetime
df.columns = [datetime.strptime(f.split("M")[0] + "-" + f.split("M")[1] + "-01", "%Y-%m-%d")
                if f.startswith("20") or f.startswith("19") else f for f in df.columns]

# %% [markdown]
# Betrachte das Ergebnis:

# %%
df
# Out:
#         indic s_adj unit country  2021-07-01 00:00:00  2021-06-01 00:00:00  \
# 0    BS-CSMCI   NSA  BAL      AL                -12.9                -13.6
# 1    BS-CSMCI   NSA  BAL      AT                  0.2                 -0.6
# 2    BS-CSMCI   NSA  BAL      BE                  2.9                  4.1
# 3    BS-CSMCI   NSA  BAL      BG                -16.5                -18.4
# 4    BS-CSMCI   NSA  BAL      CY                -23.5                -10.1
# ..        ...   ...  ...     ...                  ...                  ...
# 901  BS-UE-NY    SA  BAL      SE                -16.2                -17.7
# 902  BS-UE-NY    SA  BAL      SI                 21.8                  9.3
# 903  BS-UE-NY    SA  BAL      SK                 24.3                 22.3
# 904  BS-UE-NY    SA  BAL      TR                 33.4                 28.5
# 905  BS-UE-NY    SA  BAL      UK                  NaN                  NaN
#
#      2021-05-01 00:00:00  2021-04-01 00:00:00  2021-03-01 00:00:00  \
# 0                  -15.6                -18.1                -19.8
# 1                   -0.9                -10.5                 -4.1
# 2                    1.1                 -3.5                 -3.0
# 3                  -22.2                -20.0                -23.5
# 4                  -15.8                -19.0                -22.6
# ..                   ...                  ...                  ...
# 901                 -4.5                  4.3                 13.9
# 902                 21.4                 45.4                 40.3
# 903                 32.5                 46.1                 58.9
# 904                 36.5                 36.0                 27.5
# 905                  NaN                  NaN                  NaN
#
#      2021-02-01 00:00:00  ...  1980-10-01 00:00:00  1980-09-01 00:00:00  \
# 0                  -17.1  ...                  NaN                  NaN
# 1                   -8.6  ...                  NaN                  NaN
# 2                   -5.0  ...                  NaN                  NaN
# 3                  -29.8  ...                  NaN                  NaN
# 4                  -27.4  ...                  NaN                  NaN
# ..                   ...  ...                  ...                  ...
# 901                 16.2  ...                  NaN                  NaN
# 902                 35.8  ...                  NaN                  NaN
# 903                 57.4  ...                  NaN                  NaN
# 904                 30.4  ...                  NaN                  NaN
# 905                  NaN  ...                  NaN                  NaN
#
#      1980-08-01 00:00:00  1980-07-01 00:00:00  1980-06-01 00:00:00  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ..                   ...                  ...                  ...
# 901                  NaN                  NaN                  NaN
# 902                  NaN                  NaN                  NaN
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
#
#      1980-05-01 00:00:00  1980-04-01 00:00:00  1980-03-01 00:00:00  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ..                   ...                  ...                  ...
# 901                  NaN                  NaN                  NaN
# 902                  NaN                  NaN                  NaN
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
#
#      1980-02-01 00:00:00  1980-01-01 00:00:00
# 0                    NaN                  NaN
# 1                    NaN                  NaN
# 2                    NaN                  NaN
# 3                    NaN                  NaN
# 4                    NaN                  NaN
# ..                   ...                  ...
# 901                  NaN                  NaN
# 902                  NaN                  NaN
# 903                  NaN                  NaN
# 904                  NaN                  NaN
# 905                  NaN                  NaN
#
# [906 rows x 503 columns]

# %% [markdown]
# Das sieht schon viel besser aus, aber es sind ziemlich viele Zeilen, weil sehr viele Indikatoren enthalten sind.
#
# Nun *filterst* du die Daten und nutzt nur den Indikator `BS_CSMCI` (Konsumentenvertrauen) und zwar dessen *saison-justierte Variante*:

# %%
bs = df[(df["indic"] == "BS-CSMCI") & (df["s_adj"] == "SA")]
bs
# Out:
#        indic s_adj unit    country  2021-07-01 00:00:00  2021-06-01 00:00:00  \
# 35  BS-CSMCI    SA  BAL         AL                -14.5                -14.2
# 36  BS-CSMCI    SA  BAL         AT                 -0.3                 -2.0
# 37  BS-CSMCI    SA  BAL         BE                  1.9                  2.8
# 38  BS-CSMCI    SA  BAL         BG                -17.6                -19.7
# 39  BS-CSMCI    SA  BAL         CY                -22.8                -13.4
# 40  BS-CSMCI    SA  BAL         CZ                 -7.0                 -4.9
# 41  BS-CSMCI    SA  BAL         DE                 -2.0                 -1.2
# 42  BS-CSMCI    SA  BAL         DK                  6.2                  5.9
# 43  BS-CSMCI    SA  BAL       EA19                 -4.4                 -3.3
# 44  BS-CSMCI    SA  BAL         EE                 -9.8                 -9.4
# 45  BS-CSMCI    SA  BAL         EL                -32.9                -25.6
# 46  BS-CSMCI    SA  BAL         ES                -10.2                -11.7
# 47  BS-CSMCI    SA  BAL  EU27_2020                 -5.6                 -4.5
# 48  BS-CSMCI    SA  BAL         FI                  3.3                  4.0
# 49  BS-CSMCI    SA  BAL         FR                 -4.9                 -2.5
# 50  BS-CSMCI    SA  BAL         HR                 -8.7                 -8.4
# 51  BS-CSMCI    SA  BAL         HU                -13.3                -10.4
# 52  BS-CSMCI    SA  BAL         IE                  1.9                  2.7
# 53  BS-CSMCI    SA  BAL         IT                 -3.0                 -3.2
# 54  BS-CSMCI    SA  BAL         LT                  2.8                  1.5
# 55  BS-CSMCI    SA  BAL         LU                 -3.7                  1.1
# 56  BS-CSMCI    SA  BAL         LV                -16.4                 -5.2
# 57  BS-CSMCI    SA  BAL         ME                -10.6                -10.0
# 58  BS-CSMCI    SA  BAL         MK                -20.9                -20.9
# 59  BS-CSMCI    SA  BAL         MT                  3.8                  6.0
# 60  BS-CSMCI    SA  BAL         NL                 -0.2                  5.6
# 61  BS-CSMCI    SA  BAL         PL                 -7.4                 -5.8
# 62  BS-CSMCI    SA  BAL         PT                -17.3                -13.8
# 63  BS-CSMCI    SA  BAL         RO                  NaN                  NaN
# 64  BS-CSMCI    SA  BAL         RS                  6.7                  5.2
# 65  BS-CSMCI    SA  BAL         SE                  7.9                  8.6
# 66  BS-CSMCI    SA  BAL         SI                -19.1                -18.5
# 67  BS-CSMCI    SA  BAL         SK                -17.7                -17.1
# 68  BS-CSMCI    SA  BAL         TR                -21.2                -19.2
# 69  BS-CSMCI    SA  BAL         UK                  NaN                  NaN
#
#     2021-05-01 00:00:00  2021-04-01 00:00:00  2021-03-01 00:00:00  \
# 35                -14.4                -16.3                -21.3
# 36                 -2.3                 -8.0                 -5.9
# 37                 -0.4                 -2.2                 -4.1
# 38                -22.6                -18.9                -25.2
# 39                -17.8                -18.4                -23.0
# 40                 -6.5                 -8.3                -17.1
# 41                 -4.3                 -7.9                 -8.2
# 42                  6.8                  8.4                  3.8
# 43                 -5.1                 -8.1                -10.8
# 44                -16.9                -18.1                -19.4
# 45                -22.2                -34.6                -39.5
# 46                 -9.9                -11.6                -17.4
# 47                 -6.0                 -9.0                -12.1
# 48                  2.4                  4.4                 -2.6
# 49                 -5.8                 -8.2                -10.5
# 50                 -6.2                -10.5                -14.9
# 51                -17.1                -18.4                -23.5
# 52                  6.6                  5.7                 -2.4
# 53                 -4.5                -10.1                -11.5
# 54                 -0.3                  2.9                 -1.5
# 55                 -1.6                 -0.6                 -8.4
# 56                 -8.9                 -7.2                -19.1
# 57                 -6.5                -14.1                -20.1
# 58                -21.2                -21.9                -24.0
# 59                  8.3                  5.2                 -7.9
# 60                  3.0                  0.8                 -4.1
# 61                 -3.4                 -8.2                -13.2
# 62                -12.8                -14.6                -22.4
# 63                  NaN                  NaN                  NaN
# 64                  4.3                  2.9                  1.4
# 65                  9.5                  6.2                  4.2
# 66                -18.0                -22.5                -25.5
# 67                -18.2                -17.1                -27.8
# 68                -21.9                -19.4                -14.0
# 69                  NaN                  NaN                  NaN
#
#     2021-02-01 00:00:00  ...  1980-10-01 00:00:00  1980-09-01 00:00:00  \
# 35                -18.9  ...                  NaN                  NaN
# 36                -11.4  ...                  NaN                  NaN
# 37                 -6.2  ...                  NaN                  NaN
# 38                -30.9  ...                  NaN                  NaN
# 39                -31.8  ...                  NaN                  NaN
# 40                -16.0  ...                  NaN                  NaN
# 41                -12.0  ...                  NaN                  NaN
# 42                  2.5  ...                  NaN                  NaN
# 43                -14.8  ...                  NaN                  NaN
# 44                -16.9  ...                  NaN                  NaN
# 45                -46.2  ...                  NaN                  NaN
# 46                -25.2  ...                  NaN                  NaN
# 47                -15.7  ...                  NaN                  NaN
# 48                 -1.4  ...                  NaN                  NaN
# 49                -15.1  ...                  NaN                  NaN
# 50                -19.8  ...                  NaN                  NaN
# 51                -25.7  ...                  NaN                  NaN
# 52                 -5.2  ...                  NaN                  NaN
# 53                -13.6  ...                  NaN                  NaN
# 54                 -3.3  ...                  NaN                  NaN
# 55                -11.1  ...                  NaN                  NaN
# 56                -18.3  ...                  NaN                  NaN
# 57                -12.4  ...                  NaN                  NaN
# 58                -23.9  ...                  NaN                  NaN
# 59                 -6.9  ...                  NaN                  NaN
# 60                 -7.9  ...                  NaN                  NaN
# 61                -13.8  ...                  NaN                  NaN
# 62                -28.0  ...                  NaN                  NaN
# 63                  NaN  ...                  NaN                  NaN
# 64                  5.4  ...                  NaN                  NaN
# 65                  4.9  ...                  NaN                  NaN
# 66                -24.7  ...                  NaN                  NaN
# 67                -28.3  ...                  NaN                  NaN
# 68                -15.0  ...                  NaN                  NaN
# 69                  NaN  ...                  NaN                  NaN
#
#     1980-08-01 00:00:00  1980-07-01 00:00:00  1980-06-01 00:00:00  \
# 35                  NaN                  NaN                  NaN
# 36                  NaN                  NaN                  NaN
# 37                  NaN                  NaN                  NaN
# 38                  NaN                  NaN                  NaN
# 39                  NaN                  NaN                  NaN
# 40                  NaN                  NaN                  NaN
# 41                  NaN                  NaN                  NaN
# 42                  NaN                  NaN                  NaN
# 43                  NaN                  NaN                  NaN
# 44                  NaN                  NaN                  NaN
# 45                  NaN                  NaN                  NaN
# 46                  NaN                  NaN                  NaN
# 47                  NaN                  NaN                  NaN
# 48                  NaN                  NaN                  NaN
# 49                  NaN                  NaN                  NaN
# 50                  NaN                  NaN                  NaN
# 51                  NaN                  NaN                  NaN
# 52                  NaN                  NaN                  NaN
# 53                  NaN                  NaN                  NaN
# 54                  NaN                  NaN                  NaN
# 55                  NaN                  NaN                  NaN
# 56                  NaN                  NaN                  NaN
# 57                  NaN                  NaN                  NaN
# 58                  NaN                  NaN                  NaN
# 59                  NaN                  NaN                  NaN
# 60                  NaN                  NaN                  NaN
# 61                  NaN                  NaN                  NaN
# 62                  NaN                  NaN                  NaN
# 63                  NaN                  NaN                  NaN
# 64                  NaN                  NaN                  NaN
# 65                  NaN                  NaN                  NaN
# 66                  NaN                  NaN                  NaN
# 67                  NaN                  NaN                  NaN
# 68                  NaN                  NaN                  NaN
# 69                  NaN                  NaN                  NaN
#
#     1980-05-01 00:00:00  1980-04-01 00:00:00  1980-03-01 00:00:00  \
# 35                  NaN                  NaN                  NaN
# 36                  NaN                  NaN                  NaN
# 37                  NaN                  NaN                  NaN
# 38                  NaN                  NaN                  NaN
# 39                  NaN                  NaN                  NaN
# 40                  NaN                  NaN                  NaN
# 41                  NaN                  NaN                  NaN
# 42                  NaN                  NaN                  NaN
# 43                  NaN                  NaN                  NaN
# 44                  NaN                  NaN                  NaN
# 45                  NaN                  NaN                  NaN
# 46                  NaN                  NaN                  NaN
# 47                  NaN                  NaN                  NaN
# 48                  NaN                  NaN                  NaN
# 49                  NaN                  NaN                  NaN
# 50                  NaN                  NaN                  NaN
# 51                  NaN                  NaN                  NaN
# 52                  NaN                  NaN                  NaN
# 53                  NaN                  NaN                  NaN
# 54                  NaN                  NaN                  NaN
# 55                  NaN                  NaN                  NaN
# 56                  NaN                  NaN                  NaN
# 57                  NaN                  NaN                  NaN
# 58                  NaN                  NaN                  NaN
# 59                  NaN                  NaN                  NaN
# 60                  NaN                  NaN                  NaN
# 61                  NaN                  NaN                  NaN
# 62                  NaN                  NaN                  NaN
# 63                  NaN                  NaN                  NaN
# 64                  NaN                  NaN                  NaN
# 65                  NaN                  NaN                  NaN
# 66                  NaN                  NaN                  NaN
# 67                  NaN                  NaN                  NaN
# 68                  NaN                  NaN                  NaN
# 69                  NaN                  NaN                  NaN
#
#     1980-02-01 00:00:00  1980-01-01 00:00:00
# 35                  NaN                  NaN
# 36                  NaN                  NaN
# 37                  NaN                  NaN
# 38                  NaN                  NaN
# 39                  NaN                  NaN
# 40                  NaN                  NaN
# 41                  NaN                  NaN
# 42                  NaN                  NaN
# 43                  NaN                  NaN
# 44                  NaN                  NaN
# 45                  NaN                  NaN
# 46                  NaN                  NaN
# 47                  NaN                  NaN
# 48                  NaN                  NaN
# 49                  NaN                  NaN
# 50                  NaN                  NaN
# 51                  NaN                  NaN
# 52                  NaN                  NaN
# 53                  NaN                  NaN
# 54                  NaN                  NaN
# 55                  NaN                  NaN
# 56                  NaN                  NaN
# 57                  NaN                  NaN
# 58                  NaN                  NaN
# 59                  NaN                  NaN
# 60                  NaN                  NaN
# 61                  NaN                  NaN
# 62                  NaN                  NaN
# 63                  NaN                  NaN
# 64                  NaN                  NaN
# 65                  NaN                  NaN
# 66                  NaN                  NaN
# 67                  NaN                  NaN
# 68                  NaN                  NaN
# 69                  NaN                  NaN
#
# [35 rows x 503 columns]

# %% [markdown]
# Das ist schon viel übersichtlicher, konzentriere dich nun zunächst auf Deutschland:

# %%
bs[bs["country"] == "DE"]
# Out:
#        indic s_adj unit country  2021-07-01 00:00:00  2021-06-01 00:00:00  \
# 41  BS-CSMCI    SA  BAL      DE                 -2.0                 -1.2
#
#     2021-05-01 00:00:00  2021-04-01 00:00:00  2021-03-01 00:00:00  \
# 41                 -4.3                 -7.9                 -8.2
#
#     2021-02-01 00:00:00  ...  1980-10-01 00:00:00  1980-09-01 00:00:00  \
# 41                -12.0  ...                  NaN                  NaN
#
#     1980-08-01 00:00:00  1980-07-01 00:00:00  1980-06-01 00:00:00  \
# 41                  NaN                  NaN                  NaN
#
#     1980-05-01 00:00:00  1980-04-01 00:00:00  1980-03-01 00:00:00  \
# 41                  NaN                  NaN                  NaN
#
#     1980-02-01 00:00:00  1980-01-01 00:00:00
# 41                  NaN                  NaN
#
# [1 rows x 503 columns]

# %% [markdown]
# Das Ergebnis sieht schon gut aus, allerdings benötigst du nur die Spalten mit den Monaten, hier interessiert du dich außerdem nur für Daten ab 2010. Wenn du eine `list` in `pandas` als Index verwendest, werden nur die Spalten benutzt:

# %%
bs_de = bs[bs["country"] == "DE"][[c for c in bs.columns 
                     if (isinstance(c, datetime) and c.year>=2010)]]
bs_de
# Out:
#     2021-07-01  2021-06-01  2021-05-01  2021-04-01  2021-03-01  2021-02-01  \
# 41        -2.0        -1.2        -4.3        -7.9        -8.2       -12.0
#
#     2021-01-01  2020-12-01  2020-11-01  2020-10-01  ...  2010-10-01  \
# 41       -14.0       -10.5       -11.6        -9.5  ...         0.0
#
#     2010-09-01  2010-08-01  2010-07-01  2010-06-01  2010-05-01  2010-04-01  \
# 41        -0.6        -1.8        -4.1        -9.0       -10.2        -6.2
#
#     2010-03-01  2010-02-01  2010-01-01
# 41        -8.4       -10.5       -10.8
#
# [1 rows x 139 columns]

# %% [markdown]
# Genau das wolltest du, jetzt kannst du es gleich plotten:

# %%
bs_de.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Das hat leider nicht wie gewünscht funktioniert, weil der Plot die Werte in *vielen Zeilen* benötigt. Spalten und Zeilen vertauschen nennt sich *transponieren* und das kannst du in `pandas` einfach durch die Operation `.T` erreichen:

# %%
bs_de.T.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Genau dieses Ergebnis wolltest du erreichen. Die *Corona-Krise* kannst du im Konsumindikator gut erkennen.
#
# Willst du alle Konsumindikatoren über die Länder zu einem Zeitpunkt (z.B. Juni 2021) hinweg vergleichen, bietet sich dafür eine Tabelle an. Die Daten hast du allerdings nicht in der richtigen Form zur Verfügung, weil sowohl  Konsumindikatoren als auch Länder in den Zeilen dargestellt sind. Du möchtest aber die Konsumindikatoren in den Spalten und die Länder in den Zeilen haben.
#
# Mit `pandas` geht das ganz einfach, denn dazu gibt es die Funktion `pivot`, der du einfach die Namen der Zeilen (`index`) und die Namen der Spalten (`columns`) übergibst. Zusätzlich musst du der Funktion mitteilen, welche Werte (aus den ursprünglichen Spalten) sie verwenden soll:

# %%
indic_country = df[df["s_adj"] == "SA"].pivot(index="country", columns="indic", values=datetime(2021, 6, 1))
indic_country
# Out:
# indic      BS-CSMCI  BS-FS-LY  BS-FS-NY  BS-GES-LY  BS-GES-NY  BS-MP-NY  \
# country
# AL            -14.2     -13.0       3.1      -20.5        3.5     -50.7
# AT             -2.0      -7.6       5.5      -54.9        9.6     -15.4
# BE              2.8      -4.4       4.5      -38.2       18.1      -7.1
# BG            -19.7     -16.4      -5.7      -52.6      -20.5     -36.1
# CY            -13.4     -12.9       0.3      -56.0      -10.7     -30.3
# CZ             -4.9      -4.1       4.8      -54.1      -10.8      -9.4
# DE             -1.2       0.4       3.8      -40.1       -3.2      -5.9
# DK              5.9       5.1      11.6      -14.5        5.0       2.1
# EA19           -3.3      -8.0       2.1      -49.2        3.4     -10.7
# EE             -9.4      -3.9       0.0      -15.7       -3.2     -30.6
# EL            -25.6     -28.2     -16.3      -59.6      -28.1     -29.6
# ES            -11.7     -23.2      -0.1      -73.2       -0.2     -23.2
# EU27_2020      -4.5      -7.0       1.3      -47.2       -2.6      -9.5
# FI              4.0       7.6      11.5      -28.2        5.8      -8.9
# FR             -2.5      -7.8      -0.3      -50.6       -1.6      -0.2
# HR             -8.4      -7.8       4.4      -46.9      -14.5     -15.7
# HU            -10.4     -16.1       0.4      -47.4       -9.8     -16.2
# IE              2.7      -2.2      13.1      -63.2        6.9      -6.9
# IT             -3.2     -15.9       1.5      -52.7       21.9     -20.4
# LT              1.5      -1.5       6.8      -18.9       -1.2       2.1
# LU              1.1      -0.6       1.0      -35.6       15.3     -11.4
# LV             -5.2      -2.1       9.2      -47.7      -10.1     -17.6
# ME            -10.0     -28.2      10.8      -44.1       11.6     -34.1
# MK            -20.9     -31.3      -1.3      -54.5      -10.7     -40.3
# MT              6.0     -11.0      10.4      -37.2       31.3      -6.5
# NL              5.6       0.2       8.6      -39.3       19.5      -5.7
# PL             -5.8      -5.7      -3.7      -40.8      -24.4      10.6
# PT            -13.8     -12.5      -1.2      -56.8      -12.3     -29.1
# RO              NaN       NaN       NaN        NaN        NaN       NaN
# RS              5.2      -6.1       9.0        9.0       20.1      -2.2
# SE              8.6       9.5      14.6      -15.0       12.5      -2.3
# SI            -18.5     -16.6      -9.1      -54.3      -20.6     -27.8
# SK            -17.1     -16.2      -6.1      -53.0      -25.6     -20.6
# TR            -19.2     -39.3     -18.6      -45.5      -15.2      -3.7
# UK              NaN       NaN       NaN        NaN        NaN       NaN
#
# indic      BS-MP-PR  BS-PT-LY  BS-PT-NY  BS-SFSH  BS-SV-NY  BS-SV-PR  BS-UE-NY
# country
# AL            -65.7      -3.6     -19.0      2.5     -45.6     -46.3       6.3
# AT              6.5      33.3      44.7     29.4      18.7      19.0     -13.8
# BE             12.2      52.8      21.5     29.4      25.3     -21.3       9.8
# BG            -23.0      39.2      17.3     19.2     -22.3     -12.1      15.5
# CY            -31.9     -13.0     -12.4     17.3     -32.6     -19.0      13.2
# CZ             -8.4      17.2      46.4     34.9      16.5     -10.7       8.6
# DE             -8.4      33.3      44.8     30.1      14.9      14.0      11.7
# DK             -7.6       0.4      30.0     36.2      42.9      54.9     -11.3
# EA19           -9.8      24.7      27.1     20.8       7.7       NaN      11.4
# EE            -36.2      27.7      32.0     19.8     -33.2     -34.6       5.4
# EL            -26.9       9.3      -6.5      4.7     -57.6     -40.4      29.0
# ES            -39.5      23.6      17.7      9.6     -11.1     -14.9      -2.9
# EU27_2020     -11.7      23.2      29.0     22.4       8.2       NaN      12.1
# FI             20.4       0.7      34.6     32.9      49.7      18.4      -3.8
# FR             -5.4      27.2      27.2     13.8      10.1      27.3      17.2
# HR            -21.3      36.4      23.4      3.1     -24.1      -8.2       8.7
# HU            -28.2      49.7      47.6      3.4     -28.2     -42.5      15.0
# IE              0.6      14.7      34.8     38.0      41.8      33.9      -9.4
# IT             -3.1       0.7      -4.9     11.9      -4.1      71.2      24.5
# LT              3.7      37.6      52.0     25.2       3.1       9.4       9.8
# LU             -0.8      35.7      33.9     42.1      46.4      35.3      15.3
# LV            -24.1      25.5      29.1     26.0       3.4      -8.4       5.3
# ME            -60.8      61.0       4.9      5.4     -41.7     -15.8      13.4
# MK            -47.5      54.3      19.4     -9.8     -32.9     -17.2      12.0
# MT              9.0      21.3      -8.7     30.7       3.5       1.7     -28.8
# NL             -3.8      42.1      48.8     33.3      29.8       7.6      -7.0
# PL             -1.1      50.6      54.4     12.7      -9.2     -12.7      15.5
# PT            -66.0      16.0      13.7     16.1     -18.6     -26.2      19.9
# RO              NaN       NaN       NaN      NaN       NaN       NaN       NaN
# RS            -34.0      25.0      18.0     -7.4     -61.2     -41.2     -14.9
# SE             -0.3      -2.0      27.8     50.3      51.8      21.5     -17.7
# SI            -24.1      46.3      53.6     25.2      -9.1      -5.9       9.3
# SK            -17.0      26.9      46.2     14.0     -15.9     -22.4      22.3
# TR            -63.3      77.3      36.8    -26.9     -66.9     -33.7      28.5
# UK              NaN       NaN       NaN      NaN       NaN       NaN       NaN

# %% [markdown]
# Eine etwas übersichtlichere Darstellung erreichst du mit einer sog. *Heatmap*:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 20))
sns.heatmap(indic_country, annot=True)
# Out:
# <AxesSubplot:xlabel='indic', ylabel='country'>

# %% [markdown]
# Hier siehst du auf den ersten Blick, dass Rumänien keine Werte geliefert hat und der Indikator `BS_SV_PR` für die gesamte EU bzw. den Euro-Raum nicht berechnet wurde.
